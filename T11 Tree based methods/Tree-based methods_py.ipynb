# %% [markdown]
# # T10: Tree-Based Methods
#
# - TA: HUANG Xinrui
# - Date: November 21, 2023

# %% [markdown]
# Let's import some of our usual libraries at this top level.

# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
import sklearn.model_selection as skm
from ISLP import load_data, confusion_table
from ISLP.models import ModelSpec as MS

# %% [markdown]
# We also collect the new imports needed for this lab.

# %%
from sklearn.tree import (DecisionTreeClassifier,
                          DecisionTreeRegressor,
                          plot_tree,
                          export_text)
from sklearn.metrics import (accuracy_score,
                             log_loss)
from sklearn.ensemble import \
     (RandomForestRegressor,
      GradientBoostingRegressor)
from ISLP.bart import BART

# %% [markdown]
# ## Classification trees
#
# - We first use classification trees to analyze the `Carseats` data set.
# - In these data, `Sales` is a continuous variable, and so we begin by recoding it as a binary variable.
# - We use the `np.where()` function to create a variable called `High`, which takes on a value of Yes if the `Sales` variable exceeds 8, and takes on a value of No otherwise.

# %%
Carseats = load_data('Carseats')
High = np.where(Carseats.Sales > 8,
                "Yes",
                "No")
#Carseats['High'] = High
#Carseats['High'] = Carseats['High'].astype('category')

# %%
Carseats.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
Carseats.shape
# Out:
# (400, 11)

# %% [markdown]
# - We now use `DecisionTreeClassifier()`  to fit a classification tree in order to predict `High` using all variables but `Sales`. To do so, we must form a model matrix as we did when fitting regression models.

# %%
model = MS(Carseats.columns.drop('Sales'), intercept=False)
D = model.fit_transform(Carseats)
feature_names = list(D.columns)
X = np.asarray(D)

# %% [markdown]
# We have converted `D` from a data frame to an array `X`, which is needed in some of the analysis below. We also need the `feature_names` for annotating our plots later.
#
# There are several options needed to specify the  classifier,
# such as `max_depth` (how deep to grow the tree), `min_samples_split`
# (minimum number of observations in a node to be eligible for splitting)
# and `criterion` (whether to use Gini or cross-entropy or log-loss as the split criterion).
# We also set `random_state` for reproducibility; ties in the split criterion are broken at random.

# %%
tree_carseats = DecisionTreeClassifier(criterion='entropy',
          max_depth=3,
          random_state=0)        
tree_carseats.fit(X, High)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %%
accuracy_score(High, tree_carseats.predict(X))
# Out:
# 0.79

# %% [markdown]
# - With only the default arguments, the training error rate is 21%.
# - For classification trees, we can
# access the value of the deviance using `log_loss()`,
# \begin{equation*}
# \begin{split}
# -2 \sum_m \sum_k n_{mk} \log \hat{p}_{mk},
# \end{split}
# \end{equation*}
# where $n_{mk}$ is the number of observations in the $m$th terminal
# node that belong to the $k$th class.
# - A small deviance indicates a tree that provides a good fit to the (training) dataset.

# %%
resid_dev = np.sum(log_loss(High, tree_carseats.predict_proba(X)))
resid_dev
# Out:
# 0.4710647062649358

# %% [markdown]
# - This is closely related to the *entropy*. A small deviance indicates a
# tree that provides a good fit to the (training) data.
#
# - One of the most attractive properties of trees is that they can
# be graphically displayed. Here we use the `plot()`  function
# to display the tree structure.

# %%
ax = subplots(figsize=(12,12))[1]
plot_tree(tree_carseats,
          feature_names=feature_names,
          ax=ax);

# %% [markdown]
# - The most important indicator of `Sales` appears to be `ShelveLoc`.
#
# - We can see a text representation of the tree using
# `export_text()`, which displays the split
# criterion (e.g. `Price <= 92.5`) for each branch.
#
# - For leaf nodes it shows the overall prediction (`Yes` or `No`). We can also see the number of observations in that leaf that take on values of `Yes` and `No` by specifying  `show_weights=True`.

# %%
print(export_text(tree_carseats,
                  feature_names=feature_names,
                  show_weights=True))
# Out:
# |--- ShelveLoc[Good] <= 0.50
# |   |--- Price <= 92.50
# |   |   |--- Income <= 57.00
# |   |   |   |--- weights: [7.00, 3.00] class: No
# |   |   |--- Income >  57.00
# |   |   |   |--- weights: [7.00, 29.00] class: Yes
# |   |--- Price >  92.50
# |   |   |--- Advertising <= 13.50
# |   |   |   |--- weights: [183.00, 41.00] class: No
# |   |   |--- Advertising >  13.50
# |   |   |   |--- weights: [20.00, 25.00] class: Yes
# |--- ShelveLoc[Good] >  0.50
# |   |--- Price <= 135.00
# |   |   |--- US[Yes] <= 0.50
# |   |   |   |--- weights: [6.00, 11.00] class: Yes
# |   |   |--- US[Yes] >  0.50
# |   |   |   |--- weights: [2.00, 49.00] class: Yes
# |   |--- Price >  135.00
# |   |   |--- Income <= 46.00
# |   |   |   |--- weights: [6.00, 0.00] class: No
# |   |   |--- Income >  46.00
# |   |   |   |--- weights: [5.00, 6.00] class: Yes

# %% [markdown]
# - In order to properly evaluate the performance of a classification tree
# on these data, we must estimate the test error rather than simply
# computing the training error.
# - We split the observations into a
# training set and a test set, build the tree using the training set,
# and evaluate its performance on the test data.
# - This pattern is
# similar to that in Chapter 6, with the linear models
# replaced here by decision trees --- the code for validation
# is almost identical. This approach leads to correct predictions
# for 68.5% of the locations in the test data set.

# %%
validation = skm.ShuffleSplit(n_splits=1,
                              test_size=200,
                              random_state=0)
results = skm.cross_validate(tree_carseats,
                             D,
                             High,
                             cv=validation)
results['test_score']
# Out:
# array([0.685])

# %% [markdown]
# ## * Tree pruning
# ​
# <font color='red'>Tree pruning is not usually used in practice. So we directly skip this part. You can take a look at it if you're interested.</font>
# ​
# - Next, we consider whether pruning the tree might lead to improved results.
# - We first split the data into a training and
# test set. We will use cross-validation to prune the tree on the training
# set, and then evaluate the performance of the pruned tree on the test
# set..

# %%
(X_train,
 X_test,
 High_train,
 High_test) = skm.train_test_split(X,
                                   High,
                                   test_size=0.5,
                                   random_state=0)

# %% [markdown]
# - We first refit the full tree on the training set; here we do not set a `max_depth` parameter, since we will learn that through cross-validation.

# %%
tree_carseats = DecisionTreeClassifier(criterion='entropy', random_state=0)
tree_carseats.fit(X_train, High_train)
accuracy_score(High_test, tree_carseats.predict(X_test))
# Out:
# 0.735

# %% [markdown]
# - Next we use the `cost_complexity_pruning_path()` method to extract cost-complexity values.

# %%
ccp_path = tree_carseats.cost_complexity_pruning_path(X_train, High_train)
kfold = skm.KFold(10,
                  random_state=1,
                  shuffle=True)

# %% [markdown]
# - This yields a set of impurities and $\alpha$ values
# from which we can extract an optimal one by cross-validation.

# %%
grid = skm.GridSearchCV(tree_carseats,
                        {'ccp_alpha': ccp_path.ccp_alphas},
                        refit=True,
                        cv=kfold,
                        scoring='accuracy')
grid.fit(X_train, High_train)
grid.best_score_
# Out:
# 0.685

# %% [markdown]
# Let’s take a look at the pruned true.

# %%
ax = subplots(figsize=(12, 12))[1]
best_ = grid.best_estimator_
plot_tree(best_,
          feature_names=feature_names,
          ax=ax);

# %% [markdown]
# - This is quite a bushy tree. We could count the leaves, or query
# `best_` instead.

# %%
best_.tree_.n_leaves
# Out:
# 30

# %% [markdown]
# - The tree with 30 terminal
# nodes results in the lowest cross-validation error rate, with an accuracy of
# 68.5%. How well does this pruned tree perform on the test data set? Once
# again, we apply the `predict()`  function.

# %%
print(accuracy_score(High_test,
                     best_.predict(X_test)))
confusion = confusion_table(best_.predict(X_test),
                            High_test)
confusion
# Out:
# 0.72
# Truth      No  Yes
# Predicted
# No         94   32
# Yes        24   50

# %% [markdown]
# - Now 72.0% of the test observations are correctly classified, which is slightly worse than the error for the full tree (with 35 leaves).
# - So cross-validation has not helped us much here; it only pruned off 5 leaves, at a cost of a slightly worse error.
# - These results would change if we were to change the random number seeds above; even though cross-validation gives an unbiased approach to model selection, it does have variance.

# %% [markdown]
# ## Regression trees
#
# - Here we fit a regression tree to the `Boston` data set.  The steps are similar to those for classification trees.

# %%
Boston = load_data("Boston")
model = MS(Boston.columns.drop('medv'), intercept=False)
D = model.fit_transform(Boston)
feature_names = list(D.columns)
X = np.asarray(D)

# %%
Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
Boston.shape
# Out:
# (506, 13)

# %% [markdown]
# - First, we create a training set and fit the tree to the training data. Here we use half of the data for the test set.

# %%
(X_train,
 X_test,
 y_train,
 y_test) = skm.train_test_split(X,
                                Boston['medv'],
                                test_size=0.5,
                                random_state=0)

# %% [markdown]
# - Having formed  our training  and test data sets, we fit the regression tree.

# %%
tree_boston = DecisionTreeRegressor(max_depth=3)
tree_boston.fit(X_train, y_train)
ax = subplots(figsize=(12,12))[1]
plot_tree(tree_boston,
          feature_names=feature_names,
          ax=ax);

# %% [markdown]
# - The variable `lstat` measures the percentage of individuals with
# lower socioeconomic status. The tree indicates that lower
# values of `lstat` correspond to more expensive houses.
#
# - In the context of a regression tree, deviance is simply the sum of squared errors for the tree.

# %% [markdown]
# - Now we use the cross-validation function to see whether pruning
# the tree will improve performance.

# %%
ccp_path = tree_boston.cost_complexity_pruning_path(X_train, y_train)
kfold = skm.KFold(5,
                  shuffle=True,
                  random_state=10)
grid = skm.GridSearchCV(tree_boston,
                        {'ccp_alpha': ccp_path.ccp_alphas},
                        refit=True,
                        cv=kfold,
                        scoring='neg_mean_squared_error')
G = grid.fit(X_train, y_train)

# %% [markdown]
# - In keeping with the cross-validation results, we use the pruned tree
# to make predictions on the test set.

# %%
best_ = grid.best_estimator_
np.mean((y_test - best_.predict(X_test))**2)
# Out:
# 26.02323085009744

# %% [markdown]
# - In other words, the test set MSE associated with the regression tree
# is 26.23.  The square root of
# the MSE is therefore around
# 5.12,
# indicating that this model leads to test predictions that are within around
# $5120
# of the true median home value for the suburb.
#
# - Let’s plot the best tree to see how interpretable it is.

# %%
ax = subplots(figsize=(12,12))[1]
plot_tree(G.best_estimator_,
          feature_names=feature_names,
          ax=ax);

# %% [markdown]
# ## Bagging and Random Forest
# - Here we apply bagging and random forests to the `Boston` dataset using
# the `RandomForestRegressor()` from the `sklearn.ensemble` package.
# - Recall that bagging is simply a special case of a random forest with $m = p$.
# - Therefore, the `RandomForestRegressor()` function can be used to perform both random forests and bagging.
# - We perform bagging as follows:

# %%
bag_boston = RandomForestRegressor(max_features=X_train.shape[1], random_state=0)
bag_boston.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features=12, random_state=0)

# %% [markdown]
# - The argument `max_features` indicates that all 12 predictors should
# be considered for each split of the tree --- in other words, that
# bagging should be done.
# - How well does this bagged model perform on
# the test set?

# %%
ax = subplots(figsize=(8,8))[1]
y_hat_bag = bag_boston.predict(X_test)
ax.scatter(y_hat_bag, y_test)
np.mean((y_test - y_hat_bag)**2)
# Out:
# 15.998719418972334

# %% [markdown]
# - The test set MSE associated with the bagged regression tree is
# 16.00, about half that obtained using an optimally-pruned single
# tree.
# - We could change the number of trees grown from the default of 100 by
# using the `n_estimators` argument:

# %%
bag_boston = RandomForestRegressor(max_features=X_train.shape[1],
                n_estimators=500,
                random_state=0).fit(X_train, y_train)
y_hat_bag = bag_boston.predict(X_test)
np.mean((y_test - y_hat_bag)**2)
# Out:
# 16.248098012490143

# %% [markdown]
# - There is not much change. Bagging and random forests cannot overfit by
# increasing the number of trees, but can underfit if the number is too small.
#
# - Growing a random forest proceeds in exactly the same way, except that
# we use a smaller value of the `max_features` argument. By default,
# `RandomForestRegressor()`  uses $p$ variables when building a random
# forest of regression trees (i.e. it defaults to bagging), and `RandomForestClassifier()` uses
# $\sqrt{p}$ variables when building a
# random forest of classification trees.
# - Here we use `max_features=6`.

# %%
RF_boston = RandomForestRegressor(max_features=6,
               random_state=0).fit(X_train, y_train)
y_hat_RF = RF_boston.predict(X_test)
np.mean((y_test - y_hat_RF)**2)
# Out:
# 16.17286237944664

# %% [markdown]
# - The test set MSE is 16.17;
# this indicates that random forests and bagging perform similarly
# in this case.
# - Extracting the `feature_importances_` values from the fitted model, we can view the
# importance of each variable.

# %%
feature_imp = pd.DataFrame(
    {'importance':RF_boston.feature_importances_},
    index=feature_names)
feature_imp.sort_values(by='importance', ascending=False)
# Out:
#          importance
# lstat      0.361067
# rm         0.337409
# ptratio    0.071866
# crim       0.053653
# dis        0.042531
# indus      0.037716
# nox        0.032038
# age        0.031782
# tax        0.022377
# rad        0.003801
# chas       0.003309
# zn         0.002451

# %% [markdown]
# - This is a relative measure of the total decrease in node impurity that results from
# splits over that variable, averaged over all trees.
#
# - The results indicate that across all of the trees considered in the
# random forest, the wealth level of the community (`lstat`) and the
# house size (`rm`) are by far the two most important variables.

# %% [markdown]
# ## * Random Forest: Randomization and regularization
#
# Here we take a close look at why the randomized splitting procedure in random forest often improves prediction.
# We will see that the randomization has the regularization effect, as demonstrated by analyzing the __degrees of freedom__.

# %%
n = 100
p = 10
s = 5
SNR = 1
nrep = 10

X = np.random.normal(size=(n, p))

beta = np.zeros(p)
beta[:s] = 1

y0 = X.dot(beta)

sige = np.sum(beta**2) / SNR

mtry_all = np.array([0.1, 0.3, 0.5, 0.7, 1]) * p
# The 'max_leaf_nodes' parameter of RandomForestRegressor must be an int in the range [2, inf) or None.
# So we change the first element of nodes_all from 1 to 2.
nodes_all = np.array([2, 5, 10, 15, 20])
out = pd.DataFrame()

for i in range(nrep):
    y = y0 + np.random.normal(0, np.sqrt(sige), n)
    for j in range(len(mtry_all)):
        for k in range(len(nodes_all)):
            fit_rf = RandomForestRegressor(n_estimators=100, max_features=int(mtry_all[j]), max_leaf_nodes=nodes_all[k])
            fit_rf.fit(X, y)
            df = np.cov(y, fit_rf.predict(X)) / sige
            out = out.append({'df': df[0,1], 'mtry': f"mtry={mtry_all[j]}", 'maxnodes': nodes_all[k]}, ignore_index=True)
            print(f"{i+1}-th repetition, {j+1}-th mtry, {k+1}-th node finished.")
# Out:
# 1-th repetition, 1-th mtry, 1-th node finished.
# 1-th repetition, 1-th mtry, 2-th node finished.
# 1-th repetition, 1-th mtry, 3-th node finished.
# 1-th repetition, 1-th mtry, 4-th node finished.
# 1-th repetition, 1-th mtry, 5-th node finished.
# 1-th repetition, 2-th mtry, 1-th node finished.
# 1-th repetition, 2-th mtry, 2-th node finished.
# 1-th repetition, 2-th mtry, 3-th node finished.
# 1-th repetition, 2-th mtry, 4-th node finished.
# 1-th repetition, 2-th mtry, 5-th node finished.
# 1-th repetition, 3-th mtry, 1-th node finished.
# 1-th repetition, 3-th mtry, 2-th node finished.
# 1-th repetition, 3-th mtry, 3-th node finished.
# 1-th repetition, 3-th mtry, 4-th node finished.
# 1-th repetition, 3-th mtry, 5-th node finished.
# 1-th repetition, 4-th mtry, 1-th node finished.
# 1-th repetition, 4-th mtry, 2-th node finished.
# 1-th repetition, 4-th mtry, 3-th node finished.
# 1-th repetition, 4-th mtry, 4-th node finished.
# 1-th repetition, 4-th mtry, 5-th node finished.
# 1-th repetition, 5-th mtry, 1-th node finished.
# 1-th repetition, 5-th mtry, 2-th node finished.
# 1-th repetition, 5-th mtry, 3-th node finished.
# 1-th repetition, 5-th mtry, 4-th node finished.
# 1-th repetition, 5-th mtry, 5-th node finished.
# 2-th repetition, 1-th mtry, 1-th node finished.
# 2-th repetition, 1-th mtry, 2-th node finished.
# 2-th repetition, 1-th mtry, 3-th node finished.
# 2-th repetition, 1-th mtry, 4-th node finished.
# 2-th repetition, 1-th mtry, 5-th node finished.
# 2-th repetition, 2-th mtry, 1-th node finished.
# 2-th repetition, 2-th mtry, 2-th node finished.
# 2-th repetition, 2-th mtry, 3-th node finished.
# 2-th repetition, 2-th mtry, 4-th node finished.
# 2-th repetition, 2-th mtry, 5-th node finished.
# 2-th repetition, 3-th mtry, 1-th node finished.
# 2-th repetition, 3-th mtry, 2-th node finished.
# 2-th repetition, 3-th mtry, 3-th node finished.
# 2-th repetition, 3-th mtry, 4-th node finished.
# 2-th repetition, 3-th mtry, 5-th node finished.
# 2-th repetition, 4-th mtry, 1-th node finished.
# 2-th repetition, 4-th mtry, 2-th node finished.
# 2-th repetition, 4-th mtry, 3-th node finished.
# 2-th repetition, 4-th mtry, 4-th node finished.
# 2-th repetition, 4-th mtry, 5-th node finished.
# 2-th repetition, 5-th mtry, 1-th node finished.
# 2-th repetition, 5-th mtry, 2-th node finished.
# 2-th repetition, 5-th mtry, 3-th node finished.
# 2-th repetition, 5-th mtry, 4-th node finished.
# 2-th repetition, 5-th mtry, 5-th node finished.
# 3-th repetition, 1-th mtry, 1-th node finished.
# 3-th repetition, 1-th mtry, 2-th node finished.
# 3-th repetition, 1-th mtry, 3-th node finished.
# 3-th repetition, 1-th mtry, 4-th node finished.
# 3-th repetition, 1-th mtry, 5-th node finished.
# 3-th repetition, 2-th mtry, 1-th node finished.
# 3-th repetition, 2-th mtry, 2-th node finished.
# 3-th repetition, 2-th mtry, 3-th node finished.
# 3-th repetition, 2-th mtry, 4-th node finished.
# 3-th repetition, 2-th mtry, 5-th node finished.
# 3-th repetition, 3-th mtry, 1-th node finished.
# 3-th repetition, 3-th mtry, 2-th node finished.
# 3-th repetition, 3-th mtry, 3-th node finished.
# 3-th repetition, 3-th mtry, 4-th node finished.
# 3-th repetition, 3-th mtry, 5-th node finished.
# 3-th repetition, 4-th mtry, 1-th node finished.
# 3-th repetition, 4-th mtry, 2-th node finished.
# 3-th repetition, 4-th mtry, 3-th node finished.
# 3-th repetition, 4-th mtry, 4-th node finished.
# 3-th repetition, 4-th mtry, 5-th node finished.
# 3-th repetition, 5-th mtry, 1-th node finished.
# 3-th repetition, 5-th mtry, 2-th node finished.
# 3-th repetition, 5-th mtry, 3-th node finished.
# 3-th repetition, 5-th mtry, 4-th node finished.
# 3-th repetition, 5-th mtry, 5-th node finished.
# 4-th repetition, 1-th mtry, 1-th node finished.
# 4-th repetition, 1-th mtry, 2-th node finished.
# 4-th repetition, 1-th mtry, 3-th node finished.
# 4-th repetition, 1-th mtry, 4-th node finished.
# 4-th repetition, 1-th mtry, 5-th node finished.
# 4-th repetition, 2-th mtry, 1-th node finished.
# 4-th repetition, 2-th mtry, 2-th node finished.
# 4-th repetition, 2-th mtry, 3-th node finished.
# 4-th repetition, 2-th mtry, 4-th node finished.
# 4-th repetition, 2-th mtry, 5-th node finished.
# 4-th repetition, 3-th mtry, 1-th node finished.
# 4-th repetition, 3-th mtry, 2-th node finished.
# 4-th repetition, 3-th mtry, 3-th node finished.
# 4-th repetition, 3-th mtry, 4-th node finished.
# 4-th repetition, 3-th mtry, 5-th node finished.
# 4-th repetition, 4-th mtry, 1-th node finished.
# 4-th repetition, 4-th mtry, 2-th node finished.
# 4-th repetition, 4-th mtry, 3-th node finished.
# 4-th repetition, 4-th mtry, 4-th node finished.
# 4-th repetition, 4-th mtry, 5-th node finished.
# 4-th repetition, 5-th mtry, 1-th node finished.
# 4-th repetition, 5-th mtry, 2-th node finished.
# 4-th repetition, 5-th mtry, 3-th node finished.
# 4-th repetition, 5-th mtry, 4-th node finished.
# 4-th repetition, 5-th mtry, 5-th node finished.
# 5-th repetition, 1-th mtry, 1-th node finished.
# 5-th repetition, 1-th mtry, 2-th node finished.
# 5-th repetition, 1-th mtry, 3-th node finished.
# 5-th repetition, 1-th mtry, 4-th node finished.
# 5-th repetition, 1-th mtry, 5-th node finished.
# 5-th repetition, 2-th mtry, 1-th node finished.
# 5-th repetition, 2-th mtry, 2-th node finished.
# 5-th repetition, 2-th mtry, 3-th node finished.
# 5-th repetition, 2-th mtry, 4-th node finished.
# 5-th repetition, 2-th mtry, 5-th node finished.
# 5-th repetition, 3-th mtry, 1-th node finished.
# 5-th repetition, 3-th mtry, 2-th node finished.
# 5-th repetition, 3-th mtry, 3-th node finished.
# 5-th repetition, 3-th mtry, 4-th node finished.
# 5-th repetition, 3-th mtry, 5-th node finished.
# 5-th repetition, 4-th mtry, 1-th node finished.
# 5-th repetition, 4-th mtry, 2-th node finished.
# 5-th repetition, 4-th mtry, 3-th node finished.
# 5-th repetition, 4-th mtry, 4-th node finished.
# 5-th repetition, 4-th mtry, 5-th node finished.
# 5-th repetition, 5-th mtry, 1-th node finished.
# 5-th repetition, 5-th mtry, 2-th node finished.
# 5-th repetition, 5-th mtry, 3-th node finished.
# 5-th repetition, 5-th mtry, 4-th node finished.
# 5-th repetition, 5-th mtry, 5-th node finished.
# 6-th repetition, 1-th mtry, 1-th node finished.
# 6-th repetition, 1-th mtry, 2-th node finished.
# 6-th repetition, 1-th mtry, 3-th node finished.
# 6-th repetition, 1-th mtry, 4-th node finished.
# 6-th repetition, 1-th mtry, 5-th node finished.
# 6-th repetition, 2-th mtry, 1-th node finished.
# 6-th repetition, 2-th mtry, 2-th node finished.
# 6-th repetition, 2-th mtry, 3-th node finished.
# 6-th repetition, 2-th mtry, 4-th node finished.
# 6-th repetition, 2-th mtry, 5-th node finished.
# 6-th repetition, 3-th mtry, 1-th node finished.
# 6-th repetition, 3-th mtry, 2-th node finished.
# 6-th repetition, 3-th mtry, 3-th node finished.
# 6-th repetition, 3-th mtry, 4-th node finished.
# 6-th repetition, 3-th mtry, 5-th node finished.
# 6-th repetition, 4-th mtry, 1-th node finished.
# 6-th repetition, 4-th mtry, 2-th node finished.
# 6-th repetition, 4-th mtry, 3-th node finished.
# 6-th repetition, 4-th mtry, 4-th node finished.
# 6-th repetition, 4-th mtry, 5-th node finished.
# 6-th repetition, 5-th mtry, 1-th node finished.
# 6-th repetition, 5-th mtry, 2-th node finished.
# 6-th repetition, 5-th mtry, 3-th node finished.
# 6-th repetition, 5-th mtry, 4-th node finished.
# 6-th repetition, 5-th mtry, 5-th node finished.
# 7-th repetition, 1-th mtry, 1-th node finished.
# 7-th repetition, 1-th mtry, 2-th node finished.
# 7-th repetition, 1-th mtry, 3-th node finished.
# 7-th repetition, 1-th mtry, 4-th node finished.
# 7-th repetition, 1-th mtry, 5-th node finished.
# 7-th repetition, 2-th mtry, 1-th node finished.
# 7-th repetition, 2-th mtry, 2-th node finished.
# 7-th repetition, 2-th mtry, 3-th node finished.
# 7-th repetition, 2-th mtry, 4-th node finished.
# 7-th repetition, 2-th mtry, 5-th node finished.
# 7-th repetition, 3-th mtry, 1-th node finished.
# 7-th repetition, 3-th mtry, 2-th node finished.
# 7-th repetition, 3-th mtry, 3-th node finished.
# 7-th repetition, 3-th mtry, 4-th node finished.
# 7-th repetition, 3-th mtry, 5-th node finished.
# 7-th repetition, 4-th mtry, 1-th node finished.
# 7-th repetition, 4-th mtry, 2-th node finished.
# 7-th repetition, 4-th mtry, 3-th node finished.
# 7-th repetition, 4-th mtry, 4-th node finished.
# 7-th repetition, 4-th mtry, 5-th node finished.
# 7-th repetition, 5-th mtry, 1-th node finished.
# 7-th repetition, 5-th mtry, 2-th node finished.
# 7-th repetition, 5-th mtry, 3-th node finished.
# 7-th repetition, 5-th mtry, 4-th node finished.
# 7-th repetition, 5-th mtry, 5-th node finished.
# 8-th repetition, 1-th mtry, 1-th node finished.
# 8-th repetition, 1-th mtry, 2-th node finished.
# 8-th repetition, 1-th mtry, 3-th node finished.
# 8-th repetition, 1-th mtry, 4-th node finished.
# 8-th repetition, 1-th mtry, 5-th node finished.
# 8-th repetition, 2-th mtry, 1-th node finished.
# 8-th repetition, 2-th mtry, 2-th node finished.
# 8-th repetition, 2-th mtry, 3-th node finished.
# 8-th repetition, 2-th mtry, 4-th node finished.
# 8-th repetition, 2-th mtry, 5-th node finished.
# 8-th repetition, 3-th mtry, 1-th node finished.
# 8-th repetition, 3-th mtry, 2-th node finished.
# 8-th repetition, 3-th mtry, 3-th node finished.
# 8-th repetition, 3-th mtry, 4-th node finished.
# 8-th repetition, 3-th mtry, 5-th node finished.
# 8-th repetition, 4-th mtry, 1-th node finished.
# 8-th repetition, 4-th mtry, 2-th node finished.
# 8-th repetition, 4-th mtry, 3-th node finished.
# 8-th repetition, 4-th mtry, 4-th node finished.
# 8-th repetition, 4-th mtry, 5-th node finished.
# 8-th repetition, 5-th mtry, 1-th node finished.
# 8-th repetition, 5-th mtry, 2-th node finished.
# 8-th repetition, 5-th mtry, 3-th node finished.
# 8-th repetition, 5-th mtry, 4-th node finished.
# 8-th repetition, 5-th mtry, 5-th node finished.
# 9-th repetition, 1-th mtry, 1-th node finished.
# 9-th repetition, 1-th mtry, 2-th node finished.
# 9-th repetition, 1-th mtry, 3-th node finished.
# 9-th repetition, 1-th mtry, 4-th node finished.
# 9-th repetition, 1-th mtry, 5-th node finished.
# 9-th repetition, 2-th mtry, 1-th node finished.
# 9-th repetition, 2-th mtry, 2-th node finished.
# 9-th repetition, 2-th mtry, 3-th node finished.
# 9-th repetition, 2-th mtry, 4-th node finished.
# 9-th repetition, 2-th mtry, 5-th node finished.
# 9-th repetition, 3-th mtry, 1-th node finished.
# 9-th repetition, 3-th mtry, 2-th node finished.
# 9-th repetition, 3-th mtry, 3-th node finished.
# 9-th repetition, 3-th mtry, 4-th node finished.
# 9-th repetition, 3-th mtry, 5-th node finished.
# 9-th repetition, 4-th mtry, 1-th node finished.
# 9-th repetition, 4-th mtry, 2-th node finished.
# 9-th repetition, 4-th mtry, 3-th node finished.
# 9-th repetition, 4-th mtry, 4-th node finished.
# 9-th repetition, 4-th mtry, 5-th node finished.
# 9-th repetition, 5-th mtry, 1-th node finished.
# 9-th repetition, 5-th mtry, 2-th node finished.
# 9-th repetition, 5-th mtry, 3-th node finished.
# 9-th repetition, 5-th mtry, 4-th node finished.
# 9-th repetition, 5-th mtry, 5-th node finished.
# 10-th repetition, 1-th mtry, 1-th node finished.
# 10-th repetition, 1-th mtry, 2-th node finished.
# 10-th repetition, 1-th mtry, 3-th node finished.
# 10-th repetition, 1-th mtry, 4-th node finished.
# 10-th repetition, 1-th mtry, 5-th node finished.
# 10-th repetition, 2-th mtry, 1-th node finished.
# 10-th repetition, 2-th mtry, 2-th node finished.
# 10-th repetition, 2-th mtry, 3-th node finished.
# 10-th repetition, 2-th mtry, 4-th node finished.
# 10-th repetition, 2-th mtry, 5-th node finished.
# 10-th repetition, 3-th mtry, 1-th node finished.
# 10-th repetition, 3-th mtry, 2-th node finished.
# 10-th repetition, 3-th mtry, 3-th node finished.
# 10-th repetition, 3-th mtry, 4-th node finished.
# 10-th repetition, 3-th mtry, 5-th node finished.
# 10-th repetition, 4-th mtry, 1-th node finished.
# 10-th repetition, 4-th mtry, 2-th node finished.
# 10-th repetition, 4-th mtry, 3-th node finished.
# 10-th repetition, 4-th mtry, 4-th node finished.
# 10-th repetition, 4-th mtry, 5-th node finished.
# 10-th repetition, 5-th mtry, 1-th node finished.
# 10-th repetition, 5-th mtry, 2-th node finished.
# 10-th repetition, 5-th mtry, 3-th node finished.
# 10-th repetition, 5-th mtry, 4-th node finished.
# 10-th repetition, 5-th mtry, 5-th node finished.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

out1 = out.groupby(['mtry', 'maxnodes']).mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='maxnodes', y='df', hue='mtry', style='mtry', data=out1)
plt.xlabel('maxnodes')
plt.ylabel('df')
plt.show()
